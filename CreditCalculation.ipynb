# %%
print('Witaj! Pomogę Ci obliczyć ratę Twojego kredytu.')
print('Podaj kwotę kredytu w PLN (np. 20000).')
while True:
    try:
        k=float(input())
    except ValueError:
        print("Proszę podać poprawną wartość!")
        continue
    else:
        if(k>0):
            break
        else:
            print("Proszę podać kwotę większą od 0!")
print('Podaj przez ile miesięcy chcesz spłacać kredyt (np. 36).')
while True:
    try:
        n=int(input())
    except ValueError:
        print("Proszę podać poprawną wartość!")
        continue
    else:
        if(n>0):
            break
        else:
            print("Proszę podać wartość większą od 0!")
print('Podaj roczną stopę procentową (np. 13.5).')
while True:
    try:
        s=float(input())
    except ValueError:
        print("Proszę podać poprawną wartość!")
        continue
    else:
        if(s>0):
            break
        else:
            print("Proszę podać oprocentowanie większe niż 0!")
print('Podaj prowizję kredytu (np. 4.5 - Jeśli kredyt jest udzielany bez prowizji wpisz "0").')
while True:
    try:
        pro=float(input())
    except ValueError:
        print("Proszę podać poprawną wartość!")
        continue
    else:
        break
try:
    if (pro != 0):
        pro=pro/100
        prok = k*pro
        k=k+prok
    q=1+((s/12)/100)
    r=k*q**n*((q-1)/(q**n-1))
    print('----------------------------------------------------------------------------------')
    print('Rata Twojego kredytu wynosi ' + "%.2f" % r + 'zł')
    ck = r*n
    print('Całkowita kwota jaką musisz zwrócić do banku to '+ "%.2f" % ck + 'zł')
    if (pro != 0):
        print('Całkowity koszt kredytu wyniesie ' + "%.2f" % (ck - (k-prok)) + 'zł')
    else:
        print('Całkowity koszt kredytu wyniesie ' + "%.2f" % (ck - k) + 'zł')
    averageS = 6.51
    if (s > averageS):
        differenceS = s - averageS
        print('Oprocentowanie Twojego kredytu jest większe niż średnie roczne oprocentowanie w 2020 roku o ' + "%.2f" % differenceS + '%.')
    elif (s < averageS):
        differenceS = averageS - s
        print('Oprocentowanie Twojego kredytu jest niższe niż średnie roczne oprocentowanie w 2020 roku o ' + "%.2f" % differenceS + '%.')
    else:
        print('Oprocentowanie Twojego kredytu jest dokładnie takie samo jak średnie roczne oprocentowanie w 2020 roku.')
    print('----------------------------------------------------------------------------------')

    #Alior Bank
    try:
        ABs=11.2
        q=1+((ABs/12)/100)
        ABr=k*q**n*((q-1)/(q**n-1))
        print('Rata Twojego kredytu w Alior Banku mogłaby wynosić ' + "%.2f" % ABr + 'zł')
    except ZeroDivisionError:
        print("Wprowadziłeś niepoprawne dane! Wystąpił błąd dzielenia przez 0.")

    #mBank
    try:
        mBs=14.66
        q=1+((mBs/12)/100)
        mBr=k*q**n*((q-1)/(q**n-1))
        print('Rata Twojego kredytu w mBanku mogłaby wynosić ' + "%.2f" % mBr + 'zł')
    except ZeroDivisionError:
        print("Wprowadziłeś niepoprawne dane! Wystąpił błąd dzielenia przez 0.")

    #Santander
    try:
        Ss=12.22
        q=1+((Ss/12)/100)
        Sr=k*q**n*((q-1)/(q**n-1))
        print('Rata Twojego kredytu w Santander mogłaby wynosić ' + "%.2f" % Sr + 'zł')
    except ZeroDivisionError:
        print("Wprowadziłeś niepoprawne dane! Wystąpił błąd dzielenia przez 0.")

    #Milenium
    try:
        Ms=15.32
        q=1+((Ms/12)/100)
        Mr=k*q**n*((q-1)/(q**n-1))
        print('Rata Twojego kredytu w Milenium mogłaby wynosić ' + "%.2f" % Mr + 'zł')
    except ZeroDivisionError:
        print("Wprowadziłeś niepoprawne dane! Wystąpił błąd dzielenia przez 0.")

    #Wykres
    import numpy as np
    import matplotlib.pyplot as plt
    height = [1,2,3,4,5]
    height[0] = s
    height[1] = ABs
    height[2] = mBs
    height[3] = Ss
    height[4] = Ms
    bars = ('A', 'B', 'C', 'D', 'E')
    y_pos = np.arange(len(bars))
    plt.bar(y_pos, height, color=(0.2, 0.4, 0.6, 0.6))
    plt.tick_params(axis='x', colors='red', direction='out', length=13, width=3)

    print('\n' + 'Poniższy wykres przedstawia porównanie Twojego oprocentowania z przykładowymi rocznymi stopami procentowymi w innych bankach:' + '\n' + '0 - Twoje oprocentowanie' + '\n' + '1 - Oprocentowanie w Alior Banku' + '\n' + '2 - Oprocentowanie w mBanku' + '\n' + '3 - Oprocentowanie w Santander Banku' + '\n' + '4 - Oprocentowanie w Milenium')
except ZeroDivisionError:
    print('\n' + "Wprowadziłeś niepoprawne dane! Wystąpił błąd dzielenia przez 0." + '\n' + "Uruchom program ponownie i wprowadź odpowiednie wartości.")
# Out:
# Witaj! Pomogę Ci obliczyć ratę Twojego kredytu.
# Podaj kwotę kredytu w PLN (np. 20000).
# -2
# Proszę podać kwotę większą od 0!
# 0
# Proszę podać kwotę większą od 0!
# 10000.5
# Podaj przez ile miesięcy chcesz spłacać kredyt (np. 36).
# 12.5
# Proszę podać poprawną wartość!
# -8
# Proszę podać wartość większą od 0!
# 0
# Proszę podać wartość większą od 0!
# 36
# Podaj roczną stopę procentową (np. 13.5).
# -5
# Proszę podać oprocentowanie większe niż 0!
# 0
# Proszę podać oprocentowanie większe niż 0!
# 12.5
# Podaj prowizję kredytu (np. 4.5 - Jeśli kredyt jest udzielany bez prowizji wpisz "0").
# 0
# ----------------------------------------------------------------------------------
# Rata Twojego kredytu wynosi 334.55zł
# Całkowita kwota jaką musisz zwrócić do banku to 12043.91zł
# Całkowity koszt kredytu wyniesie 2043.41zł
# Oprocentowanie Twojego kredytu jest większe niż średnie roczne oprocentowanie w 2020 roku o 5.99%.
# ...
